# %% [markdown]
# ## Connection SSH
#
# Voir: https://www.raspberrypi.org/documentation/computers/remote-access.html
#
# * login: pi
# * password: raspberry
# * 192.168.2.4
#
# ```
# Utiliser -Y pour exporter le serveur graphique
# ssh -Y pi@192.168.2.4
# ssh pi@192.168.2.4
# ssh -L 8889:localhost:8888 pi@192.168.2.4
#
#
#
# ```
#
# ## Spec
#
# * 15GB disk
# * 3.7GB RAM
# * 4 cores, ARMv7 Processor rev 3 (v7l) - 32 bits
#
# ```
# PRETTY_NAME="Raspbian GNU/Linux 10 (buster)"
# NAME="Raspbian GNU/Linux"
# VERSION_ID="10"
# VERSION="10 (buster)"
# VERSION_CODENAME=buster
# ID=raspbian
# ID_LIKE=debian
# HOME_URL="http://www.raspbian.org/"
# SUPPORT_URL="http://www.raspbian.org/RaspbianForums"
# BUG_REPORT_URL="http://www.raspbian.org/RaspbianBugs"
#
# Python 3.7.3 (default, Jan 22 2021, 20:04:44)
# [GCC 8.3.0] on linux
#
# pi@astro-pi-kit:~  uname -a
# Linux astro-pi-kit 5.10.52-v7l+ #1441 SMP Tue Aug 3 18:11:56 BST 2021 armv7l GNU/Linux
#
# ```
#
#
#
# ## Jupyter notebook
#
# Maybe not!
#
# https://www.instructables.com/Jupyter-Notebook-on-Raspberry-Pi/
#
# ```
# sudo su -
# apt-get update
# apt-get install python3-matplotlib
# apt-get install python3-scipy
# pip3 install --upgrade pip
# reboot
# sudo pip3 install jupyter
#
# sudo apt-get clean
# pip3 install --upgrade --force jupyter-console
# ```
#
#
# ## Scratch
#
# https://pimylifeup.com/raspberry-pi-scratch/
#
# ```
# sudo apt install scratch3
# ```
#
# Extnsions:
# * https://sheeptester.github.io/scratch-gui/
# * https://www.instructables.com/Making-Scratch-30-Extensions/
# * https://kittenbot.github.io/scratch3-extension/#
#
#
# ## Setup wifi
#
# ```
# sudo raspi-config
#
# sudo nano /etc/wpa_supplicant/wpa_supplicant.conf
#
# ctrl_interface=DIR=/var/run/wpa_supplicant GROUP=netdev
# update_config=1
# country=GB
#
# network={
#  ssid="sciento_2.4Ghz"
#  scan_ssid=1
#  psk="sciento0!"
#  key_mgmt=WPA-PSK
# }
#
#
# network={
#  ssid="Le Terrier_5"
#  scan_ssid=1
#  psk="R@bbitH0le"
#  key_mgmt=WPA-PSK
# }
#
# network={
#  ssid="AMERICA"
#  scan_ssid=1
#  psk="fuckyeah"
#  key_mgmt=WPA-PSK
# }
#
#
# ## VNC
#
# * Voir https://www.ionos.fr/digitalguide/serveur/configuration/mise-en-place-dun-vnc-sur-raspberry-pi/
# * Client pour Mac: https://www.tweaking4all.com/os-tips-and-tricks/macosx-tips-and-tricks/best-vnc-client-macos-x/

# %% [markdown]
# ## Tutoriels:
#
#
# ### Installation et premiers tests
#
# Voir https://www.esa.int/Education/AstroPI/Getting_started_with_Astro_Pi_-_teach_with_space_T05.1
#
# * Guide en français (enseignants): https://eserobelgium.be/wp-content/uploads/2018/07/T05.1b_Getting-started-with-astro-pi_teqcher-guide_FR.pdf
# * Guide en français (élèves): https://eserobelgium.be/wp-content/uploads/2018/07/T05.1b_Getting-started-with-astro-pi_student-activities_FR.pdf
#
# Aussi
#
# * https://projects.raspberrypi.org/fr-FR/projects/raspberry-pi-getting-started - Raspberry 3 ?
#
# ### Mission 0
#
# * En français, pour dernier AstroPi https://projects.raspberrypi.org/fr-FR/projects/astro-pi-mission-zero
# * https://astro-pi.org/mission-zero/resources
#
# ### Mission space
#
# * https://astro-pi.org/mission-space-lab/resources
#
# ### Autres ressources
#
# * En anglais(ou français une fois sur chaque page): https://astro-pi.org/mission-space-lab/resources
# * Camera: https://projects.raspberrypi.org/fr-FR/projects/getting-started-with-picamera
#
# ## Docker
#
#
# https://linuxhint.com/install_docker_raspberry_pi-2/
#
# ```
# pi@astro-pi-kit:~  docker --version
# Docker version 20.10.10, build b485636
#
# https://hub.docker.com/r/bitnami/pytorch
# docker run -it --name pytorch bitnami/pytorch
# docker run -it --name alpine alpine:latest
#
# docker images alpine:latest --format "{{.Repository}}:{{.Tag}} -> {{.Size}}"
#
#
# docker images bitnami/pytorch --format "{{.Repository}}:{{.Tag}} -> {{.Size}}"
#
# ```
#
# https://tcoil.info/build-custom-miniconda-docker-image-with-dockerfile/
#
#
# ## Pytorch
#
# Difficile
#
# https://qengineering.eu/install-pytorch-on-raspberry-pi-4.html
#
#
# ## Coral
#
# * Coral API: https://coral.ai/docs/reference/py/
# * On Arduino nano : https://github.com/googlecreativelab/teachablemachine-community/blob/master/snippets/markdown/tiny_image/GettingStarted.md
#
# * https://projects.raspberrypi.org/en/projects/image-id-coral/0
#
# * Installation Coral lib - Déjà faites apparemmment (apt-get install libedgetpu1-std python3-pycoral -y)
#
# ```
# wget -O - https://raw.githubusercontent.com/raspberrypilearning/image-id-coral/master/en/resources/install_script.sh | bash
#
# ```
#
# Download ISS images from https://drive.google.com/drive/folders/1owb4zoZzSMld5qX0edCwZ1qZ6ypnJQ_5 (1.5GB)
#
# ```
# scp iss_day_night_images-20211105T092456Z-001.zip pi@192.168.2.4:/home/pi
# unzip iss_day_night_images-20211105T092456Z-001.zip
# rm iss_day_night_images-20211105T092456Z-001.zip
# ```
#
# Clone Git Repo (1.5GB) - Reduce to 18MB by deleting .git
#
# ```
# git clone https://github.com/raspberrypilearning/image-id-coral
#
# cd image-id-coral
# rm -rf .git
#
# cd en/ressources
# mkdir data
# mv day-vs-night.txt data
# mv ~/iss_day_night_images/* data/
#
# mkdir models
# mv mobilenet_v1_1.0_224_l2norm_quant_edgetpu.tflite models
#
# ```
#
# Instructions from Teachable Machine - Coral
#
# ```
# pip3 install Pillow opencv-python opencv-contrib-python
#
# ```

# %% [markdown]
# ### Keras on computer
#
# ```
# pip install --upgrade tensorflow -> Installs 2.6
# pip install keras -> Installs 2.6
#
# ```
